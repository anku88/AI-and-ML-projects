# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split

# %%
columns=['userId','productId','rating','timestamp']

# %%
df_ratings=pd.read_csv('Electronic_dataset.csv')

# %%
df_ratings.head(10)
# Out:
#                  user_id     prod_id  ratings   timestamp
# 0         A3L1GVWVJKWZZS  B0058UUR6E      5.0  1364774400
# 1  A08831071BVKZMKNCPI5S  B009ID0VVS      5.0  1357257600
# 2         A1SINU2I4IOPNU  B000GBO9IM      4.0  1358121600
# 3         A3P3P31EEOX2BD  B00CDCIOHO      3.0  1404950400
# 4         A3DBLJ3MPBJQMN  B000MS3VGA      5.0  1294444800
# 5         A3DBD19DOV8NTS  B002TOJXIA      4.0  1322006400
# 6         A2PIF6JQQYOGPG  B00007E7JU      4.0  1246060800
# 7          A9QF7T2BLAU74  B00004T8N5      5.0  1052352000
# 8         A2F4OUYS6G6LM0  B00D4FXFGO      1.0  1392249600
# 9         A39Q0LE0OJ5PMF  B00269SXT8      5.0  1347926400

# %%
df_ratings.shape
# Out:
# (500000, 4)

# %%
user_counts=df_ratings['user_id'].value_counts()

# %%
user_counts
# Out:
# A680RUE1FDO8B     36
# A3OXHLG6DIBRW8    34
# ADLVFFE4VBT8      30
# A5JLAU2ARJ0BO     29
# A2NOW4U7W3F7RI    28
#                   ..
# AQT89XVRH1YLW      1
# A3LIN4MHJ4LTT1     1
# ARMEWPRS6K5QT      1
# A1W1ILCCJR4M4N     1
# A32J3Y65XJ7NKL     1
# Name: user_id, Length: 448368, dtype: int64

# %%
df_new_users=df_ratings[df_ratings['user_id'].isin(user_counts[user_counts >= 5].index)]

# %%
df_new_users.head()
# Out:
#             user_id     prod_id  ratings   timestamp
# 26   A2HX3D3MPPASNS  B004I3VZM2      4.0  1355529600
# 214   AZNUHQSHZHSUE  B000FJEYZI      1.0  1201996800
# 264  A1YEPFLLH42OU1  B00E3W15P0      5.0  1404086400
# 286  A2GYV87WW0DMSN  B0009Y7APU      5.0  1358985600
# 326  A2IXMLO29Z5G8S  B002K46DDC      5.0  1347062400

# %%
df_new_users.shape
# Out:
# (8447, 4)

# %%
df_new_users['user_id'].value_counts()
# Out:
# A680RUE1FDO8B     36
# A3OXHLG6DIBRW8    34
# ADLVFFE4VBT8      30
# A5JLAU2ARJ0BO     29
# A2NOW4U7W3F7RI    28
#                   ..
# A1CST2WUA32GP0     5
# A1BUMO9NIT57OR     5
# A35KBAQ4VBNQ6L     5
# A3AHDR4F2J7YXX     5
# A2NDMKZIM7FOOB     5
# Name: user_id, Length: 1231, dtype: int64

# %%
df_new_users.drop('timestamp',axis=1,inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_new_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8447 entries, 26 to 499955
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   user_id  8447 non-null   object
#  1   prod_id  8447 non-null   object
#  2   ratings  8447 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 264.0+ KB

# %%
pd.DataFrame(df_new_users.groupby('user_id')['ratings'].count().sort_values(ascending=False)).head()
# Out:
#                 ratings
# user_id
# A680RUE1FDO8B        36
# A3OXHLG6DIBRW8       34
# ADLVFFE4VBT8         30
# A5JLAU2ARJ0BO        29
# A2NOW4U7W3F7RI       28

# %%
pd.DataFrame(df_new_users.groupby('prod_id')['ratings'].mean().sort_values(ascending=False).head(20))
# Out:
#             ratings
# prod_id
# B00L26YDA4      5.0
# B00065HLSI      5.0
# B003Y2V09Q      5.0
# B003Y30334      5.0
# B003Y3BFBI      5.0
# B003Y5WWTU      5.0
# B003Y6UNI6      5.0
# B003Y8DIRC      5.0
# B003YDV6N0      5.0
# B003Z6Q2JE      5.0
# B003YFHE9I      5.0
# B00064XKO8      5.0
# B003YKG2WI      5.0
# B003YKG2XM      5.0
# B003YT0I4W      5.0
# B003YVJJ5Y      5.0
# B00065U8BK      5.0
# B003Y2KC7W      5.0
# B003Y2ILES      5.0
# B003XZSZWO      5.0

# %%
pd.DataFrame(df_new_users.groupby('prod_id')['ratings'].count().sort_values(ascending=False).head(20))
# Out:
#             ratings
# prod_id
# B007WTAJTO       20
# B003ES5ZUU       18
# B0088CJT4U       11
# B002SZEOLG       11
# B005FYNSPK       10
# B006W8U2MU       10
# B00E3W15P0        9
# B002WE6D44        9
# B002V88HFE        9
# B009SYZ8OC        9
# B00829TIA4        9
# B004T9RR6I        8
# B000VX6XL6        8
# B0034CL2ZI        8
# B00829THK0        8
# B002QEBMAK        7
# B006GWO5WK        7
# B0019EHU8G        7
# B0079UAT0A        7
# B001E1Y5O6        7

# %%
ratings_mean_count=pd.DataFrame(df_new_users.groupby('prod_id')['ratings'].mean())

# %%
ratings_mean_count.sort_values(by='ratings',ascending=False).head()
# Out:
#             ratings
# prod_id
# B00L26YDA4      5.0
# B002VUCCVW      5.0
# B008LCYIEI      5.0
# B008LA7GBM      5.0
# B002VFFA5M      5.0

# %%
ratings_mean_count['ratings_count']=pd.DataFrame(df_new_users.groupby('prod_id')['ratings'].count())

# %%
ratings_mean_count.sort_values(by='ratings_count',ascending=False).head(20)
# Out:
#              ratings  ratings_count
# prod_id
# B007WTAJTO  4.400000             20
# B003ES5ZUU  5.000000             18
# B002SZEOLG  3.909091             11
# B0088CJT4U  4.363636             11
# B006W8U2MU  4.800000             10
# B005FYNSPK  4.700000             10
# B002V88HFE  4.444444              9
# B00829TIA4  4.666667              9
# B002WE6D44  4.444444              9
# B009SYZ8OC  4.666667              9
# B00E3W15P0  4.666667              9
# B000VX6XL6  4.750000              8
# B004T9RR6I  4.125000              8
# B00829THK0  4.250000              8
# B0034CL2ZI  4.375000              8
# B002QEBMAK  4.142857              7
# B0019EHU8G  4.714286              7
# B000QUUFRW  4.857143              7
# B003M0NURK  4.142857              7
# B000JMJWV2  4.428571              7

# %% [markdown]
# now from the above result we can pick top 10 products and put on the website on the basis of popularity (minimum 50 user rated the product )

# %% [markdown]
# # spliting data into training and testing data

# %%
trainDF, tempDF = train_test_split(df_new_users, test_size=0.3, random_state=0)

# %%
testDF = tempDF.copy()

# %%
tempDF.rating= np.nan
df_rat = pd.concat([trainDF, tempDF])
print("Shape:" ,df_new_users.head())
df_rat.head()
# Out:
# Shape:             user_id     prod_id  ratings
# 26   A2HX3D3MPPASNS  B004I3VZM2      4.0
# 214   AZNUHQSHZHSUE  B000FJEYZI      1.0
# 264  A1YEPFLLH42OU1  B00E3W15P0      5.0
# 286  A2GYV87WW0DMSN  B0009Y7APU      5.0
# 326  A2IXMLO29Z5G8S  B002K46DDC      5.0
#                user_id     prod_id  ratings
# 78936   A2SYAQXJGRY3XE  B00009UTZA      4.0
# 297326  A2BYV7S1QP2YIG  B00JF7LR4C      5.0
# 443551   AFNG8O2DXRCUV  B003UT6C9G      3.0
# 245378   AOCBGDKF09QLU  B003F8UWV6      5.0
# 403581  A10ZBR6O8S8OCY  B00FA4Y7N2      5.0

# %% [markdown]
# # popularity recommender model

# %%
rat_matrix = df_rat.pivot(index = 'user_id', columns ='prod_id', values = 'ratings').fillna(0)
userID = rat_matrix.index
productID = rat_matrix.columns
rat_matrix.head()
# Out:
# prod_id               1400501466  1400532655  9985511476  B000001OM4  \
# user_id
# A0655860XQH1M5Q8JH1M         0.0         0.0         0.0         0.0
# A100UD67AHFODS               0.0         0.0         0.0         0.0
# A100WO06OQR8BQ               0.0         0.0         0.0         0.0
# A105TOJ6LTVMBG               0.0         0.0         0.0         0.0
# A107D9T206Z36                0.0         0.0         0.0         0.0
#
# prod_id               B000006OQ8  B00000DM9M  B00000DM9W  B00000DMA3  \
# user_id
# A0655860XQH1M5Q8JH1M         0.0         0.0         0.0         0.0
# A100UD67AHFODS               0.0         0.0         0.0         0.0
# A100WO06OQR8BQ               0.0         0.0         0.0         0.0
# A105TOJ6LTVMBG               0.0         0.0         0.0         0.0
# A107D9T206Z36                0.0         0.0         0.0         0.0
#
# prod_id               B00000J1US  B00000J4VK  ...  B00KHA2DQM  B00KHA5G6G  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
rat_matrix_std = scaler.fit_transform(rat_matrix)

# %%
 # This diaplay column index for the product with popularity
df_mean = pd.DataFrame(rat_matrix_std).mean(axis=0)
mean_df_sorted = df_mean.sort_values(ascending=False)
mean_df_sorted.head()
# Out:
# 5491    7.352184e-16
# 2958    7.150386e-16
# 1742    6.948138e-16
# 5249    6.948138e-16
# 5391    6.847240e-16
# dtype: float64

# %%
# lets display the top 10 product with their "ProductID" and rating
popularity_df = pd.DataFrame({"ProductID": productID[mean_df_sorted.index], "MeanRating": mean_df_sorted.values})
print("\nPopularity model with top 10 products: ")
popularity_df.head(10)
# Out:
# Popularity model with top 10 products:
#     ProductID    MeanRating
# 0  B008ULPAT2  7.352184e-16
# 1  B003554BP2  7.150386e-16
# 2  B0015DYMVO  6.948138e-16
# 3  B00834SJSK  6.948138e-16
# 4  B008I21EA2  6.847240e-16
# 5  B009NHWVIA  6.746116e-16
# 6  B006RG0QC8  6.487725e-16
# 7  B004XC6GJ0  6.399791e-16
# 8  B0082E9K7U  6.255489e-16
# 9  B008EQYRRY  6.140047e-16

# %%
from surprise import KNNWithMeans
from surprise.model_selection import train_test_split
from surprise import accuracy
from surprise import Dataset
from surprise import Reader
reader=Reader(rating_scale=(1,5))

# %%
data=Dataset.load_from_df(df_new_users[['user_id','prod_id','ratings']],reader)

# %%
trainset, testset =train_test_split(data,test_size=.30)

# %%
algo = KNNWithMeans(k=5, sim_options={'name': 'cosine', 'user_based': True})
algo.fit(trainset)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
uid = str('A3BY5KCNQZXV5U')  # raw user id
iid = str('0594451647')      #raw item id

# %%
pred = algo.predict(uid, iid, verbose=True)
# Out:
# user: A3BY5KCNQZXV5U item: 0594451647 r_ui = None   est = 4.26   {'was_impossible': True, 'reason': 'User and/or item is unknown.'}

# %%
test_pred = algo.test(testset)

# %%
test_pred
# Out:
# [Prediction(uid='A131NYI56W64SI', iid='B004AXDA82', r_ui=5.0, est=4.260656292286874, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1E31LPLZBVAGI', iid='B000R9AAJA', r_ui=5.0, est=4.25, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3CW0ZLUO5X2B1', iid='B0003QER8C', r_ui=5.0, est=4.260656292286874, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A10Y058K7B96C6', iid='B003BWWLWY', r_ui=4.0, est=4.260656292286874, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2C9ZOF0R2JQTO', iid='B00IRRDHUI', r_ui=5.0, est=4.260656292286874, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2TN0U8173HM7A', iid='B001UE6MIO', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
# ...

# %%
accuracy.rmse(test_pred, verbose=True)
# Out:
# RMSE: 1.0956
# 1.095569078597366

# %%
from surprise import SVD
import collections

# %%
algo = SVD()

# %%
algo.fit(trainset)
predictions = algo.test(testset)

# %%
predictions
# Out:
# [Prediction(uid='A131NYI56W64SI', iid='B004AXDA82', r_ui=5.0, est=4.115142754375803, details={'was_impossible': False}),
#  Prediction(uid='A1E31LPLZBVAGI', iid='B000R9AAJA', r_ui=5.0, est=3.7511446914853175, details={'was_impossible': False}),
#  Prediction(uid='A3CW0ZLUO5X2B1', iid='B0003QER8C', r_ui=5.0, est=4.3227488997551475, details={'was_impossible': False}),
#  Prediction(uid='A10Y058K7B96C6', iid='B003BWWLWY', r_ui=4.0, est=4.396446995828939, details={'was_impossible': False}),
#  Prediction(uid='A2C9ZOF0R2JQTO', iid='B00IRRDHUI', r_ui=5.0, est=4.054949535321744, details={'was_impossible': False}),
#  Prediction(uid='A2TN0U8173HM7A', iid='B001UE6MIO', r_ui=5.0, est=4.1179095431532895, details={'was_impossible': False}),
#  Prediction(uid='A3IUW081KXD3PE', iid='B00902SFC4', r_ui=4.0, est=4.465808360953873, details={'was_impossible': False}),
#  Prediction(uid='A3B20R4ZAH0Y2Y', iid='B00F93IOR4', r_ui=5.0, est=4.251944366895112, details={'was_impossible': False}),
# ...

# %%
def get_top_n(predictions, n):
    # First map the predictions to each user.
    top_n = collections.defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

# %%
top_n = get_top_n(predictions, n=5)
top_n
# Out:
# defaultdict(list,
#             {'A131NYI56W64SI': [('B004AXDA82', 4.115142754375803),
#               ('B009VXIUVS', 4.115142754375803)],
#              'A1E31LPLZBVAGI': [('B000R9AAJA', 3.7511446914853175)],
#              'A3CW0ZLUO5X2B1': [('B005VTIMEQ', 4.419835882646919),
#               ('B000EXTXSI', 4.389060680483319),
#               ('B0003QER8C', 4.3227488997551475),
#               ('B004UHY8SO', 4.3227488997551475),
#               ('B000NZVR3Q', 4.3227488997551475)],
#              'A10Y058K7B96C6': [('B005FDXMJS', 4.504805666941228),
#               ('B003BWWLWY', 4.396446995828939),
#               ('B000HCT12O', 4.396446995828939),
#               ('B0088PPFP4', 4.396446995828939),
#               ('B00387EW1K', 4.396446995828939)],
#              'A2C9ZOF0R2JQTO': [('B00IRRDHUI', 4.054949535321744),
#               ('B00BWHIXMM', 4.054949535321744)],
#              'A2TN0U8173HM7A': [('B0098F5W0Q', 4.346413737146037),
# ...

# %%
# Print the recommended items for each user
for uid, user_ratings in top_n.items():
    print(uid, [iid for (iid, _) in user_ratings])
# Out:
# A131NYI56W64SI ['B004AXDA82', 'B009VXIUVS']
# A1E31LPLZBVAGI ['B000R9AAJA']
# A3CW0ZLUO5X2B1 ['B005VTIMEQ', 'B000EXTXSI', 'B0003QER8C', 'B004UHY8SO', 'B000NZVR3Q']
# A10Y058K7B96C6 ['B005FDXMJS', 'B003BWWLWY', 'B000HCT12O', 'B0088PPFP4', 'B00387EW1K']
# A2C9ZOF0R2JQTO ['B00IRRDHUI', 'B00BWHIXMM']
# A2TN0U8173HM7A ['B0098F5W0Q', 'B001UE6MIO']
# A3IUW081KXD3PE ['B00902SFC4', 'B0043M668G']
# A3B20R4ZAH0Y2Y ['B001CZ9ZEE', 'B00F93IOR4']
# A1C0SOX7DPXY65 ['B000ZJZ7OA', 'B004TGJZCA']
# A1VQHH85U7PX0 ['B000L47AHG', 'B00181C9LS', 'B001GKRM90', 'B00017LRF4', 'B00CXADBRY']
# A1BUMO9NIT57OR ['B00INNP5VU', 'B0019SHZU0', 'B008P5LFEC']
# AJJV9Z17KV6GR ['B00000JMRX']
# A2IFGGXG3YV3Y6 ['B003ZUXX4W', 'B004KM4AQY', 'B007YXRYSC', 'B00EZ9XG5I', 'B00KMRGF28']
# ACJT8MUC0LRF0 ['B003CJTQJW', 'B004YHXXKO', 'B008X9Z528']
# A1XXMNLOLKNO0I ['B00008OT2G', 'B007BJHETS', 'B0000DK3I4', 'B00GBLO0DU', 'B008NF8BKK']
# AF76AAXINSF5E ['B001DHK7RA', 'B004FSCNHQ', 'B0088O721K']
# ...

# %% [markdown]
# # summary insights

# %% [markdown]
# We have successfully recommended top 10 prediction on the basis of popularity. In collabrotive modelling we predicted the estimated ratings and we calulate the RMSE On these prediction.There after we recommended the top five product to all similar users athe basis of predictive ratings.
# As per the recorded RMSE value, we can say user based filtering is a better option.
# Lack of personalization makes the popularity based recommendation model less relevant as compared to user based one.
