# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
import pandas as pd

# %%
Iris = pd.read_csv('Iris.csv')

# %%
Iris
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# ..                    ...                  ...                   ...
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# 2                    0.2     Iris-setosa
# 3                    0.2     Iris-setosa
# 4                    0.2     Iris-setosa
# ..                   ...             ...
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
Iris.dtypes
# Out:
# Sepal Length (in cm)    float64
# Sepal Width in (cm)     float64
# Petal length (in cm)    float64
# Petal width (in cm)     float64
# Class                    object
# dtype: object

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
Iris[:10]
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa
# 5                  0.4  Iris-setosa
# 6                  0.3  Iris-setosa
# 7                  0.2  Iris-setosa
# 8                  0.2  Iris-setosa
# 9                  0.1  Iris-setosa

# %%
Iris[-10:]
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica

# %% [markdown]
# ### Find the shape of the dataset

# %%
Iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
Iris.set_index('Sepal Length (in cm)' , inplace=True)

# %%
Iris
# Out:
#                       Sepal Width in (cm)  Petal length (in cm)  \
# Sepal Length (in cm)
# 5.1                                   3.5                   1.4
# 4.9                                   3.0                   1.4
# 4.7                                   3.2                   1.3
# 4.6                                   3.1                   1.5
# 5.0                                   3.6                   1.4
# ...                                   ...                   ...
# 6.7                                   3.0                   5.2
# 6.3                                   2.5                   5.0
# 6.5                                   3.0                   5.2
# 6.2                                   3.4                   5.4
# 5.9                                   3.0                   5.1
#
#                       Petal width (in cm)           Class
# Sepal Length (in cm)
# 5.1                                   0.2     Iris-setosa
# 4.9                                   0.2     Iris-setosa
# 4.7                                   0.2     Iris-setosa
# 4.6                                   0.2     Iris-setosa
# 5.0                                   0.2     Iris-setosa
# ...                                   ...             ...
# 6.7                                   2.3  Iris-virginica
# 6.3                                   1.9  Iris-virginica
# 6.5                                   2.0  Iris-virginica
# 6.2                                   2.3  Iris-virginica
# 5.9                                   1.8  Iris-virginica
#
# [150 rows x 4 columns]

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
Iris.iloc[:,2:3]
# Out:
#                       Petal width (in cm)
# Sepal Length (in cm)
# 5.1                                   0.2
# 4.9                                   0.2
# 4.7                                   0.2
# 4.6                                   0.2
# 5.0                                   0.2
# ...                                   ...
# 6.7                                   2.3
# 6.3                                   1.9
# 6.5                                   2.0
# 6.2                                   2.3
# 5.9                                   1.8
#
# [150 rows x 1 columns]

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
Iris.iloc[:10,:1]
# Out:
#                       Sepal Width in (cm)
# Sepal Length (in cm)
# 5.1                                   3.5
# 4.9                                   3.0
# 4.7                                   3.2
# 4.6                                   3.1
# 5.0                                   3.6
# 5.4                                   3.9
# 4.6                                   3.4
# 5.0                                   3.4
# 4.4                                   2.9
# 4.9                                   3.1

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
Iris[Iris['Class'] == 'Iris-setosa']
# Out:
#                       Sepal Width in (cm)  Petal length (in cm)  \
# Sepal Length (in cm)
# 5.1                                   3.5                   1.4
# 4.9                                   3.0                   1.4
# 4.7                                   3.2                   1.3
# 4.6                                   3.1                   1.5
# 5.0                                   3.6                   1.4
# 5.4                                   3.9                   1.7
# 4.6                                   3.4                   1.4
# 5.0                                   3.4                   1.5
# 4.4                                   2.9                   1.4
# 4.9                                   3.1                   1.5
# 5.4                                   3.7                   1.5
# 4.8                                   3.4                   1.6
# 4.8                                   3.0                   1.4
# 4.3                                   3.0                   1.1
# 5.8                                   4.0                   1.2
# 5.7                                   4.4                   1.5
# 5.4                                   3.9                   1.3
# 5.1                                   3.5                   1.4
# 5.7                                   3.8                   1.7
# 5.1                                   3.8                   1.5
# 5.4                                   3.4                   1.7
# 5.1                                   3.7                   1.5
# 4.6                                   3.6                   1.0
# 5.1                                   3.3                   1.7
# 4.8                                   3.4                   1.9
# 5.0                                   3.0                   1.6
# 5.0                                   3.4                   1.6
# 5.2                                   3.5                   1.5
# 5.2                                   3.4                   1.4
# 4.7                                   3.2                   1.6
# 4.8                                   3.1                   1.6
# 5.4                                   3.4                   1.5
# 5.2                                   4.1                   1.5
# 5.5                                   4.2                   1.4
# 4.9                                   3.1                   1.5
# 5.0                                   3.2                   1.2
# 5.5                                   3.5                   1.3
# 4.9                                   3.1                   1.5
# 4.4                                   3.0                   1.3
# 5.1                                   3.4                   1.5
# 5.0                                   3.5                   1.3
# 4.5                                   2.3                   1.3
# 4.4                                   3.2                   1.3
# 5.0                                   3.5                   1.6
# 5.1                                   3.8                   1.9
# 4.8                                   3.0                   1.4
# 5.1                                   3.8                   1.6
# 4.6                                   3.2                   1.4
# 5.3                                   3.7                   1.5
# 5.0                                   3.3                   1.4
#
#                       Petal width (in cm)        Class
# Sepal Length (in cm)
# 5.1                                   0.2  Iris-setosa
# 4.9                                   0.2  Iris-setosa
# 4.7                                   0.2  Iris-setosa
# 4.6                                   0.2  Iris-setosa
# 5.0                                   0.2  Iris-setosa
# 5.4                                   0.4  Iris-setosa
# 4.6                                   0.3  Iris-setosa
# 5.0                                   0.2  Iris-setosa
# 4.4                                   0.2  Iris-setosa
# 4.9                                   0.1  Iris-setosa
# 5.4                                   0.2  Iris-setosa
# 4.8                                   0.2  Iris-setosa
# 4.8                                   0.1  Iris-setosa
# 4.3                                   0.1  Iris-setosa
# 5.8                                   0.2  Iris-setosa
# 5.7                                   0.4  Iris-setosa
# 5.4                                   0.4  Iris-setosa
# 5.1                                   0.3  Iris-setosa
# 5.7                                   0.3  Iris-setosa
# 5.1                                   0.3  Iris-setosa
# 5.4                                   0.2  Iris-setosa
# 5.1                                   0.4  Iris-setosa
# 4.6                                   0.2  Iris-setosa
# 5.1                                   0.5  Iris-setosa
# 4.8                                   0.2  Iris-setosa
# 5.0                                   0.2  Iris-setosa
# 5.0                                   0.4  Iris-setosa
# 5.2                                   0.2  Iris-setosa
# 5.2                                   0.2  Iris-setosa
# 4.7                                   0.2  Iris-setosa
# 4.8                                   0.2  Iris-setosa
# 5.4                                   0.4  Iris-setosa
# 5.2                                   0.1  Iris-setosa
# 5.5                                   0.2  Iris-setosa
# 4.9                                   0.1  Iris-setosa
# 5.0                                   0.2  Iris-setosa
# 5.5                                   0.2  Iris-setosa
# 4.9                                   0.1  Iris-setosa
# 4.4                                   0.2  Iris-setosa
# 5.1                                   0.2  Iris-setosa
# 5.0                                   0.3  Iris-setosa
# 4.5                                   0.3  Iris-setosa
# 4.4                                   0.2  Iris-setosa
# 5.0                                   0.6  Iris-setosa
# 5.1                                   0.4  Iris-setosa
# 4.8                                   0.3  Iris-setosa
# 5.1                                   0.2  Iris-setosa
# 4.6                                   0.2  Iris-setosa
# 5.3                                   0.2  Iris-setosa
# 5.0                                   0.2  Iris-setosa

# %%
Iris.set_index('Class',inplace=True)

# %%
Iris
# Out:
#                 Sepal Width in (cm)  Petal length (in cm)  Petal width (in cm)
# Class
# Iris-setosa                     3.5                   1.4                  0.2
# Iris-setosa                     3.0                   1.4                  0.2
# Iris-setosa                     3.2                   1.3                  0.2
# Iris-setosa                     3.1                   1.5                  0.2
# Iris-setosa                     3.6                   1.4                  0.2
# ...                             ...                   ...                  ...
# Iris-virginica                  3.0                   5.2                  2.3
# Iris-virginica                  2.5                   5.0                  1.9
# Iris-virginica                  3.0                   5.2                  2.0
# Iris-virginica                  3.4                   5.4                  2.3
# Iris-virginica                  3.0                   5.1                  1.8
#
# [150 rows x 3 columns]

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
Iris = pd.read_csv('Iris.csv')
Iris
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# ..                    ...                  ...                   ...
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# 2                    0.2     Iris-setosa
# 3                    0.2     Iris-setosa
# 4                    0.2     Iris-setosa
# ..                   ...             ...
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
Iris['SepalExtra'] = Iris['Sepal Length (in cm)'] * Iris['Sepal Width in (cm)']
Iris
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# ..                    ...                  ...                   ...
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class  SepalExtra
# 0                    0.2     Iris-setosa       17.85
# 1                    0.2     Iris-setosa       14.70
# 2                    0.2     Iris-setosa       15.04
# 3                    0.2     Iris-setosa       14.26
# 4                    0.2     Iris-setosa       18.00
# ..                   ...             ...         ...
# 145                  2.3  Iris-virginica       20.10
# 146                  1.9  Iris-virginica       15.75
# 147                  2.0  Iris-virginica       19.50
# 148                  2.3  Iris-virginica       21.08
# 149                  1.8  Iris-virginica       17.70
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
Iris.mean(axis=0)
# Out:
# Sepal Length (in cm)     5.843333
# Sepal Width in (cm)      3.054000
# Petal length (in cm)     3.758667
# Petal width (in cm)      1.198667
# SepalExtra              17.806533
# dtype: float64

# %%
Iris.var(axis=0)
# Out:
# Sepal Length (in cm)     0.685694
# Sepal Width in (cm)      0.188004
# Petal length (in cm)     3.113179
# Petal width (in cm)      0.582414
# SepalExtra              11.348090
# dtype: float64

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
def print_num(a,b):
    print('Sepal Length (in cm):',a)
    print('Sepal Width in (cm):',b)
    
print(Iris.iloc[4,0],Iris.iloc[4,1])
# Out:
# 5.0 3.6

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
SepalLengthRange = Iris['Sepal Length (in cm)'].max()-Iris['Sepal Length (in cm)'].min()
print ('SepalLengthRange:',SepalLengthRange)
# Out:
# SepalLengthRange: 3.6000000000000005

# %%
SepalWidthRange = Iris['Sepal Width in (cm)'].max()-Iris['Sepal Width in (cm)'].min()
print('SepalwidthRange:',SepalWidthRange)
# Out:
# SepalwidthRange: 2.4000000000000004

# %%
PetalLengthRange = Iris['Petal length (in cm)'].max()-Iris['Petal length (in cm)'].min()
print ('PetalLengthRange:',PetalLengthRange)
# Out:
# PetalLengthRange: 5.9

# %%
PetalWidthRange = Iris['Petal width (in cm)'].max()-Iris['Petal width (in cm)'].min()
print('PetalWidthRange:',PetalWidthRange)
# Out:
# PetalWidthRange: 2.4

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
Iris.sort_values(by='Petal width (in cm)',ascending=True)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 32                    5.2                  4.1                   1.5
# 13                    4.3                  3.0                   1.1
# 37                    4.9                  3.1                   1.5
# 9                     4.9                  3.1                   1.5
# 12                    4.8                  3.0                   1.4
# ..                    ...                  ...                   ...
# 140                   6.7                  3.1                   5.6
# 114                   5.8                  2.8                   5.1
# 100                   6.3                  3.3                   6.0
# 144                   6.7                  3.3                   5.7
# 109                   7.2                  3.6                   6.1
#
#      Petal width (in cm)           Class  SepalExtra
# 32                   0.1     Iris-setosa       21.32
# 13                   0.1     Iris-setosa       12.90
# 37                   0.1     Iris-setosa       15.19
# 9                    0.1     Iris-setosa       15.19
# 12                   0.1     Iris-setosa       14.40
# ..                   ...             ...         ...
# 140                  2.4  Iris-virginica       20.77
# 114                  2.4  Iris-virginica       16.24
# 100                  2.5  Iris-virginica       20.79
# 144                  2.5  Iris-virginica       22.11
# 109                  2.5  Iris-virginica       25.92
#
# [150 rows x 6 columns]

# %%
Iris.sort_values(by='Petal width (in cm)',ascending=False)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 100                   6.3                  3.3                   6.0
# 109                   7.2                  3.6                   6.1
# 144                   6.7                  3.3                   5.7
# 114                   5.8                  2.8                   5.1
# 140                   6.7                  3.1                   5.6
# ..                    ...                  ...                   ...
# 13                    4.3                  3.0                   1.1
# 37                    4.9                  3.1                   1.5
# 32                    5.2                  4.1                   1.5
# 34                    4.9                  3.1                   1.5
# 9                     4.9                  3.1                   1.5
#
#      Petal width (in cm)           Class  SepalExtra
# 100                  2.5  Iris-virginica       20.79
# 109                  2.5  Iris-virginica       25.92
# 144                  2.5  Iris-virginica       22.11
# 114                  2.4  Iris-virginica       16.24
# 140                  2.4  Iris-virginica       20.77
# ..                   ...             ...         ...
# 13                   0.1     Iris-setosa       12.90
# 37                   0.1     Iris-setosa       15.19
# 32                   0.1     Iris-setosa       21.32
# 34                   0.1     Iris-setosa       15.19
# 9                    0.1     Iris-setosa       15.19
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
del Iris['SepalExtra']

# %%
Iris
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# ..                    ...                  ...                   ...
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# 2                    0.2     Iris-setosa
# 3                    0.2     Iris-setosa
# 4                    0.2     Iris-setosa
# ..                   ...             ...
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
IrisSubset = Iris.iloc[:10,:3]

# %%
IrisSubset
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
Dataset_HR = pd.read_csv('HR.txt',delimiter='\t')

# %%
Dataset_HR
# Out:
#      Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0           Ind1       Yes   41               1       1102           1
# 1           Ind2        No   49               2        279           2
# 2           Ind3       Yes   37               1       1373           2
# 3           Ind4        No   33               2       1392           2
# 4           Ind5        No   27               1        591           2
# ...          ...       ...  ...             ...        ...         ...
# 1465     Ind1466        No   36               2        884           2
# 1466     Ind1467        No   39               1        613           2
# 1467     Ind1468        No   27               1        155           2
# 1468     Ind1469        No   49               2       1023           1
# 1469     Ind1470        No   34               1        628           2
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  ...  \
# 0                    1          2               1              1  ...
# 1                    8          1               1              1  ...
# 2                    2          2               6              1  ...
# 3                    3          4               1              1  ...
# 4                    2          1               2              1  ...
# ...                ...        ...             ...            ...  ...
# 1465                23          2               2              1  ...
# 1466                 6          1               2              1  ...
# 1467                 4          3               1              1  ...
# 1468                 2          3               2              1  ...
# 1469                 8          3               2              1  ...
#
#       RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                            1             80                 0
# 1                            4             80                 1
# 2                            2             80                 0
# 3                            3             80                 0
# 4                            4             80                 1
# ...                        ...            ...               ...
# 1465                         3             80                 1
# 1466                         1             80                 1
# 1467                         2             80                 1
# 1468                         4             80                 0
# 1469                         1             80                 0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                     8                      0                1
# 1                    10                      3                3
# 2                     7                      3                3
# 3                     8                      3                3
# 4                     6                      3                3
# ...                 ...                    ...              ...
# 1465                 17                      3                3
# 1466                  9                      5                3
# 1467                  6                      0                3
# 1468                 17                      3                2
# 1469                  6                      3                4
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                  6                   4                        0
# 1                 10                   7                        1
# 2                  0                   0                        0
# 3                  8                   7                        3
# 4                  2                   2                        2
# ...              ...                 ...                      ...
# 1465               5                   2                        0
# 1466               7                   7                        1
# 1467               6                   2                        0
# 1468               9                   6                        0
# 1469               4                   3                        1
#
#       YearsWithCurrManager
# 0                        5
# 1                        7
# 2                        0
# 3                        0
# 4                        2
# ...                    ...
# 1465                     3
# 1466                     7
# 1467                     3
# 1468                     8
# 1469                     2
#
# [1470 rows x 35 columns]

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
Dataset_HR.shape
# Out:
# (1470, 35)

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
Dataset_HR.dtypes
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
Dataset_HR.iloc[:,2:10]
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41               1       1102           1                 1          2
# 1      49               2        279           2                 8          1
# 2      37               1       1373           2                 2          2
# 3      33               2       1392           2                 3          4
# 4      27               1        591           2                 2          1
# ...   ...             ...        ...         ...               ...        ...
# 1465   36               2        884           2                23          2
# 1466   39               1        613           2                 6          1
# 1467   27               1        155           2                 4          3
# 1468   49               2       1023           1                 2          3
# 1469   34               1        628           2                 8          3
#
#       EducationField  EmployeeCount
# 0                  1              1
# 1                  1              1
# 2                  6              1
# 3                  1              1
# 4                  2              1
# ...              ...            ...
# 1465               2              1
# 1466               2              1
# 1467               1              1
# 1468               2              1
# 1469               2              1
#
# [1470 rows x 8 columns]

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
Dataset_HR.iloc[:,12:13]
# Out:
#       Gender
# 0          2
# 1          1
# 2          1
# 3          2
# 4          1
# ...      ...
# 1465       1
# 1466       1
# 1467       1
# 1468       1
# 1469       1
#
# [1470 rows x 1 columns]

# %%
Malecount = Dataset_HR['Gender']==1

# %%
Malecount.sum()
print('Malecount:',Malecount.sum())
# Out:
# Malecount: 882

# %%
Femalecount = Dataset_HR['Gender']==2
Femalecount.sum()
print('Femalecount:',Femalecount.sum())
# Out:
# Femalecount: 588

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
Dataset_HR['Age'].quantile(0.75)-Dataset_HR['Age'].quantile(0.25)
# Out:
# 13.0

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
Dataset_HR['DailyRate'].mean()
# Out:
# 802.4857142857143

# %%
Dataset_HR['DailyRate'].median()
# Out:
# 802.0

# %%
Dataset_HR['DailyRate'].var()
# Out:
# 162819.59373723628
